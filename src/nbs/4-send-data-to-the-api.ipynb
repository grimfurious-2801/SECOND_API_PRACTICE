# %%
import requests

# %%
import json

# %%
path = "/api/events/"
base_url = "http://localhost:8000"
create_endpoint = f"{base_url}{path}"

response = requests.post(create_endpoint, json={"page": "/test+", "description":"123"})
print(response.headers)
print('ok', response.ok)
if response.ok:
    data = response.json()
    print(data, type(data), data.get('items'))
else:
    print(response.text)
# Out:
# {'date': 'Mon, 09 Mar 2026 12:28:55 GMT', 'server': 'uvicorn', 'content-length': '44', 'content-type': 'application/json'}
# ok True
# {'id': 3, 'description': '123', 'page': '/test+'} <class 'dict'> None

# %%
detail_path = "/api/events/12/"
detail_endpoint = f"{base_url}{detail_path}"

response = requests.put(detail_endpoint, json={"description": "hello world"})
print(response.headers)
print('ok', response.ok)
if response.ok:
    data = response.json()
    print(data, type(data), data.get('items'))
else:
    print(response.text)
# Out:
# {'date': 'Mon, 09 Mar 2026 12:28:59 GMT', 'server': 'uvicorn', 'content-length': '47', 'content-type': 'application/json'}
# ok True
# {'id': 12, 'description': 'hello world', 'page': ''} <class 'dict'> None
