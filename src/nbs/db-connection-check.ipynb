# %%
from sqlmodel import create_engine
from sqlalchemy import text

DATABASE_URL = "postgresql+psycopg2://tsdbadmin:Dineshsairam8008@my2oashliv.mpor6xgixq.tsdb.cloud.timescale.com:36852/tsdb?sslmode=require"

engine = create_engine(DATABASE_URL)

with engine.connect() as conn:
    result = conn.execute(text("SELECT version();"))
    for row in result:
        print(row)
# Out:
# ('PostgreSQL 18.3 (Ubuntu 18.3-1.pgdg22.04+1) on aarch64-unknown-linux-gnu, compiled by gcc (Ubuntu 11.4.0-1ubuntu1~22.04.3) 11.4.0, 64-bit',)
